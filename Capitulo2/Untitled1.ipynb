# %% [markdown]
# ### Exercises

# %% [markdown]
# 1

# %%
import nltk

# %%
phrase = ['oi','asmin']
sorted(phrase)#ordem alfabética
# Out:
# ['asmin', 'oi']

# %% [markdown]
# 2

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
from nltk.corpus import  gutenberg

# %%
gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
import nltk

# %%
emma = gutenberg.words('austen-persuasion.txt')
from nltk.corpus import stopwords
stopen = stopwords.words('english')
len(set(emma))
# Out:
# 6132

# %%
from string import punctuation

# %%
len([word for word in emma if word.isalpha()])
# Out:
# 84121

# %%
len([word for word in emma if word in stopen])
# Out:
# 42322

# %%
len([word for word in emma if word in punctuation])
# Out:
# 13096

# %% [markdown]
# 3

# %%
from nltk.corpus import brown

# %%
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
brown.words(categories='news')
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
brown.words(categories='adventure')
# Out:
# ['Dan', 'Morgan', 'told', 'himself', 'he', 'would', ...]

# %% [markdown]
# 4

# %%
from nltk.corpus import inaugural
cfd = nltk.ConditionalFreqDist(
           (target, fileid[:4])
           for fileid in inaugural.fileids()
           for w in inaugural.words(fileid)
           for target in ['men','woman','people']
           if w.lower().startswith(target))
cfd.plot()

# %% [markdown]
# 8

# %%
names = nltk.corpus.names

# %%
male_names = names.words('male.txt')

# %%
female_names = names.words('female.txt')

# %%
cfd = nltk.ConditionalFreqDist(
    (fileid, name[0])
    for fileid in names.fileids()
    for name in names.words(fileid))
cfd.plot()

# %% [markdown]
# 10

# %%
url = 'http://itre.cis.upenn.edu/~myl/languagelog/archives/003993.html'
from urllib import request
response = request.urlopen(url)
raw = response.read().decode('utf8')
len(raw)
# Out:
# 17572

# %%
len(set(raw))
# Out:
# 89

# %% [markdown]
# 11

# %%
entries = nltk.corpus.cmudict.entries()
total = len(entries)

# %%
onlyone = len(set([word for word, pron in entries]))

# %%
(total-onlyone)/total*100
# Out:
# 7.688223902136282

# %% [markdown]
# 15

# %%
from nltk.corpus import brown

# %%
cfd = nltk.FreqDist(brown.words())

# %%
arr = []
for i in range(len(cfd.values())):
    if(list(cfd.values())[i]>3):
        arr.append(list(cfd.keys())[i])
arr

# %% [markdown]
# 16

# %%
def tokens_types_lexicalDiversity(genre):
    types = len(set(brown.words(categories=genre)))
    tokens = len(brown.words(categories=genre))
    lexicalDiversity = types/tokens
    return types,tokens, lexicalDiversity

# %%
types = {}
tokens = {}
lexicalDiversity = {}
for genre in brown.categories():
    ty,to, lexical = tokens_types_lexicalDiversity(genre)
    types[genre] = ty
    tokens[genre] = to
    lexicalDiversity[genre] = lexical
print(types,tokens,lexicalDiversity)
# Out:
# {'adventure': 8874, 'belles_lettres': 18421, 'editorial': 9890, 'fiction': 9302, 'government': 8181, 'hobbies': 11935, 'humor': 5017, 'learned': 16859, 'lore': 14503, 'mystery': 6982, 'news': 14394, 'religion': 6373, 'reviews': 8626, 'romance': 8452, 'science_fiction': 3233} {'adventure': 69342, 'belles_lettres': 173096, 'editorial': 61604, 'fiction': 68488, 'government': 70117, 'hobbies': 82345, 'humor': 21695, 'learned': 181888, 'lore': 110299, 'mystery': 57169, 'news': 100554, 'religion': 39399, 'reviews': 40704, 'romance': 70022, 'science_fiction': 14470} {'adventure': 0.1279743878169075, 'belles_lettres': 0.10642071451679992, 'editorial': 0.16054152327770924, 'fiction': 0.1358194136199042, 'government': 0.11667641228232811, 'hobbies': 0.14493897625842492, 'humor': 0.23125144042406084, 'learned': 0.09268890745953554, 'lore': 0.13148804612915801, 'mystery': 0.12212912592488936, 'news': 0.14314696580941583, 'religion': 0.1617553745018909, 'reviews': 0.21192020440251572, 'romance': 
# ...

# %%
import pandas as pd
pd.DataFrame([tokens,types, lexicalDiversity])
# Out:
#       adventure  belles_lettres  ...       romance  science_fiction
# 0  69342.000000   173096.000000  ...  70022.000000     14470.000000
# 1   8874.000000    18421.000000  ...   8452.000000      3233.000000
# 2      0.127974        0.106421  ...      0.120705         0.223428
#
# [3 rows x 15 columns]

# %% [markdown]
# 17

# %%
a = []
for x in list(text4.vocab()): 
    if x not in stopwords.words():
         a.append(x)
a
# Out:
# [',',
#  '.',
#  'I',
#  'The',
#  'people',
#  ';',
#  'We',
#  'us',
#  'must',
#  'upon',
#  '--',
#  'It',
#  'Government',
#  'States',
#  'great',
#  'world',
#  'may',
#  'country',
#  'shall',
#  '-',
#  'every',
#  'government',
#  'peace',
#  'nation',
#  'citizens',
#  'new',
#  "'",
#  'power',
#  'In',
#  'public',
#  'America',
#  'time',
#  'would',
#  'Constitution',
#  'nations',
#  'free',
#  'freedom',
#  'United',
#  'American',
#  'Our',
#  'And',
#  'But',
#  'made',
#  '"',
#  'make',
#  'years',
#  'good',
#  'spirit',
#  'life',
#  'Union',
#  ':',
#  'national',
#  'law',
#  'well',
#  'rights',
#  'without',
#  'never',
#  'laws',
#  'fellow',
#  'Congress',
#  'To',
#  'best',
#  'right',
#  'duty',
#  'work',
#  'hope',
#  'interests',
#  'This',
#  'liberty',
#  'justice',
#  '?',
#  'God',
#  'political',
#  'among',
#  'know',
#  'They',
#  'foreign',
#  'If',
#  'powers',
#  'long',
#  'much',
#  'many',
#  'policy',
#  'principles',
#  'part',
# ...

# %% [markdown]
# 18

# %%
list(nltk.bigrams(list(text4.vocab())))
# Out:
# [('the', 'of'),
#  ('of', ','),
#  (',', 'and'),
#  ('and', '.'),
#  ('.', 'to'),
#  ('to', 'in'),
#  ('in', 'a'),
#  ('a', 'our'),
#  ('our', 'that'),
#  ('that', 'be'),
#  ('be', 'is'),
#  ('is', 'we'),
#  ('we', 'for'),
#  ('for', 'by'),
#  ('by', 'it'),
#  ('it', 'have'),
#  ('have', 'which'),
#  ('which', 'not'),
#  ('not', 'will'),
#  ('will', 'with'),
#  ('with', 'as'),
#  ('as', 'I'),
#  ('I', 'are'),
#  ('are', 'all'),
#  ('all', 'their'),
#  ('their', 'this'),
#  ('this', 'The'),
#  ('The', 'has'),
#  ('has', 'people'),
#  ('people', ';'),
#  (';', 'its'),
#  ('its', 'or'),
#  ('or', 'from'),
#  ('from', 'We'),
#  ('We', 'on'),
#  ('on', 'but'),
#  ('but', 'been'),
#  ('been', 'us'),
#  ('us', 'can'),
#  ('can', 'my'),
#  ('my', 'no'),
#  ('no', 'an'),
#  ('an', 'who'),
#  ('who', 'must'),
#  ('must', 'upon'),
#  ('upon', '--'),
#  ('--', 'so'),
#  ('so', 'It'),
#  ('It', 'they'),
#  ('they', 'Government'),
#  ('Government', 'States'),
#  ('States', 'them'),
# ...

# %% [markdown]
# 19

# %%
modals = ['can', 'could', 'may', 'might', 'must', 'will']
for genre in brown.categories():
    fd = nltk.FreqDist([a for a in
                        brown.words(categories=genre) 
                        if a in  modals])
    print('\n'+ genre)
    fd.tabulate()
# Out:
# adventure
# could might  will   can  must   may
#   151    58    50    46    27     5
#
# belles_lettres
#   can  will could   may  must might
#   246   236   213   207   170   113
#
# editorial
#  will   can   may could  must might
#   233   121    74    56    53    39
#
# fiction
# could  must  will might   can   may
#   166    55    52    44    37     8
#
# government
#  will   may   can  must could might
#   244   153   117   102    38    13
#
# hobbies
#   can  will   may  must could might
#   268   264   131    83    58    22
#
# humor
# could   can  will  must might   may
#    30    16    13     9     8     8
#
# learned
#   can  will   may  must could might
#   365   340   324   202   159   128
#
# lore
#  will   can   may could  must might
#   175   170   165   141    96    49
#
# mystery
# could might   can  must  will   may
#   141    57    42    30    20    13
#
# news
#  will   can could   may  must might
#   389    93    86    66    50    38
#
# religion
# ...

# %% [markdown]
# 20

# %%
def word_freq(word):
    for x in brown.categories():
        fd = FreqDist(brown.words(categories = x))
        print('\n' + x)
        print(fd[word])


word_freq('a')
# Out:
# adventure
# 1354
#
# belles_lettres
# 3308
#
# editorial
# 1095
#
# fiction
# 1281
#
# government
# 867
#
# hobbies
# 1737
#
# humor
# 505
#
# learned
# 3215
#
# lore
# 2304
#
# mystery
# 1136
#
# news
# 1993
#
# religion
# 655
#
# reviews
# 874
#
# romance
# 1335
#
# science_fiction
# 222

# %% [markdown]
# 21

# %%
def word_syllabe(word):
    a = [x for x in nltk.corpus.cmudict.entries() if x[0] == word]  
    return len(a[1][1])
word_syllabe('abstract')
# Out:
# 8

# %% [markdown]
# 22

# %%
def hedge(text):
    a = list(text)
    for x in range(0, len(text),4):
        a.insert(x,'like')
    return a
    
hedge(text1)
# Out:
# ['like',
#  '[',
#  'Moby',
#  'Dick',
#  'like',
#  'by',
#  'Herman',
#  'Melville',
#  'like',
#  '1851',
#  ']',
#  'ETYMOLOGY',
#  'like',
#  '.',
#  '(',
#  'Supplied',
#  'like',
#  'by',
#  'a',
#  'Late',
#  'like',
#  'Consumptive',
#  'Usher',
#  'to',
#  'like',
#  'a',
#  'Grammar',
#  'School',
#  'like',
#  ')',
#  'The',
#  'pale',
#  'like',
#  'Usher',
#  '--',
#  'threadbare',
#  'like',
#  'in',
#  'coat',
#  ',',
#  'like',
#  'heart',
#  ',',
#  'body',
#  'like',
#  ',',
#  'and',
#  'brain',
#  'like',
#  ';',
#  'I',
#  'see',
#  'like',
#  'him',
#  'now',
#  '.',
#  'like',
#  'He',
#  'was',
#  'ever',
#  'like',
#  'dusting',
#  'his',
#  'old',
#  'like',
#  'lexicons',
#  'and',
#  'grammars',
#  'like',
#  ',',
#  'with',
#  'a',
#  'like',
#  'queer',
#  'handkerchief',
#  ',',
#  'like',
#  'mockingly',
#  'embellished',
#  'with',
#  'like',
#  'all',
#  'the',
#  'gay',
#  'like',
#  'flags',
#  'of',
#  'all',
#  'like',
#  'the',
#  'known',
# ...
